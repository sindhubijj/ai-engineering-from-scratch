# %%
import sys
print(sys.executable)
# Out:
# /Users/sindhubijj/Desktop/Career/AI Engineering/ai-engineering-from-scratch/.venv/bin/python

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.21.0

# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.11.5 (main, Aug 24 2023, 15:09:45) [Clang 14.0.3 (clang-1403.0.22.14.1)]
# /Users/sindhubijj/Desktop/Career/AI Engineering/ai-engineering-from-scratch/.venv/bin/python

# %%
# !pip --version
# Out:
# pip 26.1.2 from /Users/sindhubijj/Desktop/Career/AI Engineering/ai-engineering-from-scratch/.venv/lib/python3.11/site-packages/pip (python 3.11)

# %%
#STEP 3
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.0687906564207436), np.float64(0.9881815850981943))

# %%
#STEP 4
# %timeit np.random.randn(10000)
# Out:
# 149 μs ± 972 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1)
])

model.compile(
    optimizer='adam',
    loss='mse'
)

import numpy as np
from sklearn.model_selection import train_test_split

X = np.random.rand(100, 3)
y = np.random.rand(100)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# %%time
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1890
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1788
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1697
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1622
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1557
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1494
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1451
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1406
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1375
# Epoch 10/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1350
# CPU times: user 562 ms, sys: 89 ms, total: 651 ms
# Wall time: 739 ms

# %%
# %matplotlib inline

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/sindhubijj/Desktop/Career/AI Engineering/ai-engineering-from-scratch/.venv/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /Users/sindhubijj/Desktop/Career/AI Engineering/ai-engineering-from-scratch/.venv/lib/python3.11/site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in /Users/sindhubijj/Desktop/Career/AI Engineering/ai-engineering-from-scratch/.venv/lib/python3.11/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Users/sindhubijj/Desktop/Career/AI Engineering/ai-engineering-from-scratch/.venv/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/sindhubijj/Desktop/Career/AI Engineering/ai-engineering-from-scratch/.venv/lib/python3.11/site-packages (from scikit-learn) (3.6.0)

# %%
import os
print(os.environ.get("CUDA_VISIBLE_DEVICES"))

#%env CUDA_VISIBLE_DEVICES
# Out:
# 0

# %%
#STEP 5
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.show()

# %%
from IPython.display import Image, display
display(Image(filename="/Users/sindhubijj/Desktop/7.png"))
