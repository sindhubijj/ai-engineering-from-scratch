# %%
import random
import numpy as np

# %%
# %timeit [random.random() for _ in range(100_000)]
# Out:
# 3.48 ms ± 18.9 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit np.random.random(100_000)
# Out:
# 345 μs ± 9.26 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
